# %%
import pandas as pd
import seaborn as sb

# %%
# %matplotlib inline #jupyter notebook action

# %%
sb.get_dataset_names() #data sets from seaborn library
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sb.load_dataset('diamonds') #our chosen dataset

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sb.displot(df.carat)

# %%
sb.displot(df.depth)

# %%
len(df.query("carat > 3"))/len(df.query("carat<6"))
# Out:
# 0.0005932517612161661

# %%
len(df.query("carat > 2.5"))
# Out:
# 126

# %%
sb.displot(df.price) #target variable

# %%
df.query("x==0 or y==0 or z==0")
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
df.query("x>15 or y>15 or z>15")
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 24067   2.00    Premium     H     SI2   58.9   57.0  12210  8.09  58.90   8.06
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12

# %%
df.cut.value_counts() #count the different values
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df.color.value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
df.clarity.value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
sb.scatterplot(x=df.carat, y=df.price) # the influence of carat on price
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sb.scatterplot(x=df.depth, y=df.price)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sb.pairplot(df)

# %%
df.query("x==0 or y==0 or z==0 or carat>2.5 or y>15 or z>15").index
# Out:
# Int64Index([ 2207,  2314,  4791,  5471, 10167, 11182, 11963, 13601, 15951,
#             16283,
#             ...
#             27684, 27685, 27727, 27731, 27739, 48410, 49189, 49556, 49557,
#             51506],
#            dtype='int64', length=148)

# %%
df.drop(df.query("x==0 or y==0 or z==0 or carat>2.5 or y>15 or z>15").index,inplace=True) # delete/clean the extreme values

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53792.000000  53792.000000  53792.000000  53792.000000  53792.000000
# mean       0.793020     61.748065     57.454841   3904.287980      5.724066
# std        0.463859      1.429622      2.232999   3950.737482      1.109539
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    947.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2396.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5292.000000      6.540000
# max        2.500000     79.000000     95.000000  18823.000000      8.890000
#
#                   y             z
# count  53792.000000  53792.000000
# mean       5.726039      3.534668
# std        1.101767      0.685235
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.530000      4.030000
# ...

# %%
df.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df.clarity.unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
df.cut.replace({'Ideal':5, 'Premium':4, 'Good':2, 'Very Good':3, 'Fair':1},inplace=True)

# %%
df.color.replace({'E':2, 'I':6, 'J':7, 'H':5, 'F':3, 'G':4, 'D':1},inplace=True)

# %%
df.clarity.replace({'SI2':1, 'SI1':2, 'VS1':3, 'VS2':4, 'VVS2':5, 'VVS1':6, 'I1':7, 'IF':8},inplace=True)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    5      2        1   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      2        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      2        3   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      6        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2      7        1   63.3   58.0    335  4.34  4.35  2.75

# %%
import sklearn.linear_model as sl
import sklearn.tree as st
import sklearn.ensemble as se
import sklearn.metrics as mt
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['price'],axis = 1)
y = df.price

# %%
X_train, X_test, y_train, y_test = train_test_split(X ,y ,test_size = 0.33,random_state = 42) #Determine the randomness

# %%
model = st.DecisionTreeRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([ 6663.,  8848.,   935.,   979., 12066.,  5055.,  1666.,   810.,
#        14294.,  4668.])

# %%
y_test.values[:10]
# Out:
# array([ 7179,  8752,   875,   974, 10839,  5055,  1192,   990, 14294,
#         4790], dtype=int64)

# %%
(y_test - y_pred).abs().mean() #ערך מוחלט ולאחר מכן ממוצע = mean absolute error
# Out:
# 355.6703563917681

# %%
mt.mean_absolute_error(y_test, y_pred)
# Out:
# 355.67035639176805

# %% [markdown]
# # Model Score

# %%
model.score(X_test,y_test)
# Out:
# 0.9641206313333659

# %%
mt.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.08677928340065023

# %%
sb.scatterplot(x=y_test, y=y_pred)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
X.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   0.23    5      2        1   61.5   55.0  3.95  3.98  2.43
# 1   0.21    4      2        2   59.8   61.0  3.89  3.84  2.31
# 2   0.23    2      2        3   56.9   65.0  4.05  4.07  2.31
# 3   0.29    4      6        4   62.4   58.0  4.20  4.23  2.63
# 4   0.31    2      7        1   63.3   58.0  4.34  4.35  2.75

# %%
model.predict([[1.2,3,4,2,60,60,5,5,5]])
# Out:
# array([3862.])
